# %%
from tensor_fusion.net import ARF, TFN, LMF
import torch


input_sizes = (300, 5, 20)
hidden_sizes = (128, 32, 32)
fusion_size = 128
out_size = 1
dropouts = (0, 0, 0, 0, 0)
device = 'cpu'
dtype = torch.float32

# define a full model and a compression model
full_model = TFN(input_sizes, hidden_sizes, fusion_size, out_size, dropouts, device=device, dtype=dtype)
low_rank_model = LMF(input_sizes, hidden_sizes, fusion_size, 100, out_size, dropouts, device, dtype)
compressed_model = ARF(input_sizes, hidden_sizes, fusion_size, 100, out_size, dropouts, device=device, dtype=dtype)
# Out:
# /home/christian_lee/anaconda3/envs/tensor_fusion/lib/python3.8/site-packages/tltorch/factorized_tensors/core.py:145: UserWarning: Creating a subclass of FactorizedTensor TensorizedTensor with no name.
#   warnings.warn(f'Creating a subclass of FactorizedTensor {cls.__name__} with no name.')

# %%
from tensor_fusion.dataset import get_cmu_mosi_dataset

# get dataset
train_set, valid_set, test_set = get_cmu_mosi_dataset(binary=True, device=device, dtype=dtype)

# %%
from tensor_fusion.train import binary_map_train_ARF, binary_map_train_TFN, binary_map_train_LMF

coeff = 1e-1
lr = 1e-2

print("Train Full Model")
full_max_accuracy, full_max_model, full_result = binary_map_train_TFN(full_model, train_set, test_set, learning_rate=5e-4, print_result=True)
print("==============================")
print("Train L.R. Model")
lr_max_accuracy, lr_max_model, lr_result = binary_map_train_LMF(low_rank_model, train_set, test_set, 1e-4, print_result=True)
print("==============================")
print("Train Comp. Model")
comp_max_accuracy, comp_max_model, comp_result = binary_map_train_ARF(compressed_model, train_set, test_set, coeff, lr, print_result=True)
comp_max_model.compress()
# Out:
# Train Full Model
# Epoch 0
# Train Loss 0.6814
# Valid Loss 0.6941
# Test Bin Acc 0.4038
# Epoch 1
# Train Loss 0.5864
# Valid Loss 0.5962
# Test Bin Acc 0.7114
# Epoch 2
# Train Loss 0.4960
# Valid Loss 0.5430
# Test Bin Acc 0.7274
# Epoch 3
# Train Loss 0.4500
# Valid Loss 0.5518
# Test Bin Acc 0.7099
# Epoch 4
# Train Loss 0.3872
# Valid Loss 0.5449
# Test Bin Acc 0.7216
# Epoch     6: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 5
# Train Loss 0.3672
# Valid Loss 0.5445
# Test Bin Acc 0.7449
# Epoch 6
# Train Loss 0.2866
# Valid Loss 0.6078
# Test Bin Acc 0.7405
# Epoch 7
# Train Loss 0.2596
# Valid Loss 0.6237
# Test Bin Acc 0.7405
# Epoch     9: reducing learning rate of group 0 to 5.0000e-06.
# Epoch 8
# Train Loss 0.2431
# Valid Loss 0.6307
# Test Bin Acc 0.7347
# Epoch 9
# Train Loss 0.2335
# Valid Loss 0.6431
# Test Bin Acc 0.7376
# Epoch 10
# Train Loss 0.2307
# Valid Loss 0.6498
# Test Bin Acc 0.7362
# Epoch    12: reducing learning rate of group 0 to 5.0000e-07.
# Epoch 11
# Train Loss 0.2308
# Valid Loss 0.6589
# Test Bin Acc 0.7318
# Epoch 12
# Train Loss 0.2283
# Valid Loss 0.6589
# Test Bin Acc 0.7318
# Epoch 13
# Train Loss 0.2272
# Valid Loss 0.6589
# Test Bin Acc 0.7318
# Epoch    15: reducing learning rate of group 0 to 5.0000e-08.
# Epoch 14
# Train Loss 0.2339
# Valid Loss 0.6589
# Test Bin Acc 0.7318
# Epoch 15
# Train Loss 0.2268
# Valid Loss 0.6588
# Test Bin Acc 0.7318
# ==============================
# Train L.R. Model
# Epoch 0
# Train Loss 0.6953
# Valid Loss 0.6885
# Test Bin Acc 0.5962
# Epoch 1
# Train Loss 0.6946
# Valid Loss 0.6903
# Test Bin Acc 0.5962
# Epoch 2
# Train Loss 0.6933
# Valid Loss 0.6922
# Test Bin Acc 0.6312
# Epoch 3
# Train Loss 0.6869
# Valid Loss 0.6851
# Test Bin Acc 0.5364
# Epoch 4
# Train Loss 0.6399
# Valid Loss 0.6348
# Test Bin Acc 0.6953
# Epoch 5
# Train Loss 0.5769
# Valid Loss 0.6064
# Test Bin Acc 0.7303
# Epoch 6
# Train Loss 0.5309
# Valid Loss 0.5999
# Test Bin Acc 0.7332
# Epoch 7
# Train Loss 0.5060
# Valid Loss 0.5575
# Test Bin Acc 0.7478
# Epoch 8
# Train Loss 0.4791
# Valid Loss 0.5760
# Test Bin Acc 0.7405
# Epoch 9
# Train Loss 0.4649
# Valid Loss 0.5372
# Test Bin Acc 0.7522
# Epoch 10
# Train Loss 0.4457
# Valid Loss 0.5340
# Test Bin Acc 0.7464
# Epoch 11
# Train Loss 0.4329
# Valid Loss 0.5619
# Test Bin Acc 0.7522
# Epoch 12
# Train Loss 0.4076
# Valid Loss 0.6171
# Test Bin Acc 0.7289
# Epoch    14: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 13
# Train Loss 0.4054
# Valid Loss 0.6088
# Test Bin Acc 0.7376
# Epoch 14
# Train Loss 0.3769
# Valid Loss 0.5706
# Test Bin Acc 0.7493
# Epoch 15
# Train Loss 0.3734
# Valid Loss 0.5957
# Test Bin Acc 0.7376
# Epoch    17: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 16
# Train Loss 0.3714
# Valid Loss 0.5819
# Test Bin Acc 0.7449
# Epoch 17
# Train Loss 0.3675
# Valid Loss 0.5827
# Test Bin Acc 0.7449
# Epoch 18
# Train Loss 0.3673
# Valid Loss 0.5824
# Test Bin Acc 0.7449
# Epoch    20: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 19
# Train Loss 0.3670
# Valid Loss 0.5848
# Test Bin Acc 0.7434
# Epoch 20
# Train Loss 0.3666
# Valid Loss 0.5847
# Test Bin Acc 0.7434
# Epoch 21
# Train Loss 0.3666
# Valid Loss 0.5848
# Test Bin Acc 0.7434
# Epoch    23: reducing learning rate of group 0 to 1.0000e-08.
# Epoch 22
# Train Loss 0.3666
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 23
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 24
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 25
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 26
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 27
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 28
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 29
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 30
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 31
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 32
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 33
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 34
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 35
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 36
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 37
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 38
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 39
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 40
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 41
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 42
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 43
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 44
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 45
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 46
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 47
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 48
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# Epoch 49
# Train Loss 0.3665
# Valid Loss 0.5849
# Test Bin Acc 0.7434
# ==============================
# Train Comp. Model
# Epoch 0
# Train Loss 21852.6676
# Valid Loss 0.6987
# Test Bin Acc. 0.4038
# Current Rank Est. 100
# Epoch 1
# Train Loss 35983875432235824.0000
# Valid Loss 0.5843
# Test Bin Acc. 0.7143
# Current Rank Est. 97
# Epoch 2
# Train Loss 96923787920191184.0000
# Valid Loss 0.5542
# Test Bin Acc. 0.7376
# Current Rank Est. 91
# Epoch 3
# Train Loss 52247995953331824.0000
# Valid Loss 0.6881
# Test Bin Acc. 0.6895
# Current Rank Est. 89
# Epoch 4
# Train Loss 233480206169688800.0000
# Valid Loss 0.5880
# Test Bin Acc. 0.7099
# Current Rank Est. 80
# Epoch 5
# Train Loss 115066603018675168.0000
# Valid Loss 0.5239
# Test Bin Acc. 0.7522
# Current Rank Est. 79
# Epoch 6
# Train Loss 112102231165057072.0000
# Valid Loss 0.5588
# Test Bin Acc. 0.7434
# Current Rank Est. 75
# Epoch 7
# Train Loss 169227791695705760.0000
# Valid Loss 0.6285
# Test Bin Acc. 0.7055
# Current Rank Est. 72
# Epoch     9: reducing learning rate of group 0 to 5.0000e-05.
# Epoch     9: reducing learning rate of group 1 to 1.0000e-03.
# Epoch 8
# Train Loss 215990447657656128.0000
# Valid Loss 0.5566
# Test Bin Acc. 0.7522
# Current Rank Est. 71
# Epoch 9
# Train Loss 17804990478619324.0000
# Valid Loss 0.5953
# Test Bin Acc. 0.7449
# Current Rank Est. 66
# Epoch 10
# Train Loss 588323838083471.6250
# Valid Loss 0.6280
# Test Bin Acc. 0.7449
# Current Rank Est. 67
# Epoch    12: reducing learning rate of group 0 to 5.0000e-06.
# Epoch    12: reducing learning rate of group 1 to 1.0000e-04.
# Epoch 11
# Train Loss 102872405252345.7500
# Valid Loss 0.6602
# Test Bin Acc. 0.7420
# Current Rank Est. 65
# Epoch 12
# Train Loss 944792797483.7073
# Valid Loss 0.6545
# Test Bin Acc. 0.7391
# Current Rank Est. 65
# Epoch 13
# Train Loss 11515546688.0000
# Valid Loss 0.6537
# Test Bin Acc. 0.7391
# Current Rank Est. 64
# Epoch    15: reducing learning rate of group 0 to 5.0000e-07.
# Epoch    15: reducing learning rate of group 1 to 1.0000e-05.
# Epoch 14
# Train Loss 151493794.6341
# Valid Loss 0.6569
# Test Bin Acc. 0.7376
# Current Rank Est. 64
# Epoch 15
# Train Loss 2739707.9855
# Valid Loss 0.6567
# Test Bin Acc. 0.7376
# Current Rank Est. 64
# Epoch 16
# Train Loss 284380.4596
# Valid Loss 0.6576
# Test Bin Acc. 0.7376
# Current Rank Est. 64
# Epoch    18: reducing learning rate of group 0 to 5.0000e-08.
# Epoch    18: reducing learning rate of group 1 to 1.0000e-06.
# Epoch 17
# Train Loss 131665.3958
# Valid Loss 0.6579
# Test Bin Acc. 0.7376
# Current Rank Est. 64

# %%
rank = comp_max_model.fusion_layer.max_rank
low_rank_model_2 = LMF(input_sizes, hidden_sizes, fusion_size, rank, out_size, dropouts, device, dtype)
print("==============================")
print("Train L.R. Model 2")
lr_max_accuracy_2, lr_max_model_2, lr_result_2 = binary_map_train_LMF(low_rank_model_2, train_set, test_set, 1e-4, print_result=True)
# Out:
# ==============================
# Train L.R. Model 2
# Epoch 0
# Train Loss 0.6919
# Valid Loss 0.6997
# Test Bin Acc 0.4038
# Epoch 1
# Train Loss 0.6918
# Valid Loss 0.7002
# Test Bin Acc 0.4038
# Epoch 2
# Train Loss 0.6914
# Valid Loss 0.6999
# Test Bin Acc 0.4038
# Epoch 3
# Train Loss 0.6875
# Valid Loss 0.6895
# Test Bin Acc 0.4111
# Epoch 4
# Train Loss 0.6581
# Valid Loss 0.6201
# Test Bin Acc 0.7216
# Epoch 5
# Train Loss 0.5671
# Valid Loss 0.5690
# Test Bin Acc 0.7230
# Epoch 6
# Train Loss 0.5069
# Valid Loss 0.5637
# Test Bin Acc 0.7289
# Epoch 7
# Train Loss 0.4804
# Valid Loss 0.5623
# Test Bin Acc 0.7245
# Epoch 8
# Train Loss 0.4575
# Valid Loss 0.6101
# Test Bin Acc 0.7143
# Epoch 9
# Train Loss 0.4390
# Valid Loss 0.5646
# Test Bin Acc 0.7332
# Epoch    11: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 10
# Train Loss 0.4204
# Valid Loss 0.5972
# Test Bin Acc 0.7187
# Epoch 11
# Train Loss 0.3949
# Valid Loss 0.5617
# Test Bin Acc 0.7347
# Epoch 12
# Train Loss 0.3926
# Valid Loss 0.5789
# Test Bin Acc 0.7303
# Epoch 13
# Train Loss 0.3884
# Valid Loss 0.5734
# Test Bin Acc 0.7318
# Epoch    15: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 14
# Train Loss 0.3859
# Valid Loss 0.5818
# Test Bin Acc 0.7347
# Epoch 15
# Train Loss 0.3835
# Valid Loss 0.5816
# Test Bin Acc 0.7347
# Epoch 16
# Train Loss 0.3834
# Valid Loss 0.5828
# Test Bin Acc 0.7347
# Epoch    18: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 17
# Train Loss 0.3832
# Valid Loss 0.5816
# Test Bin Acc 0.7347
# Epoch 18
# Train Loss 0.3828
# Valid Loss 0.5817
# Test Bin Acc 0.7347
# Epoch 19
# Train Loss 0.3828
# Valid Loss 0.5818
# Test Bin Acc 0.7347
# Epoch    21: reducing learning rate of group 0 to 1.0000e-08.
# Epoch 20
# Train Loss 0.3828
# Valid Loss 0.5818
# Test Bin Acc 0.7347
# Epoch 21
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 22
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 23
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 24
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 25
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 26
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 27
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 28
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 29
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 30
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 31
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 32
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 33
# Train Loss 0.3828
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 34
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 35
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 36
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 37
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 38
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 39
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 40
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 41
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 42
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 43
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 44
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 45
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 46
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 47
# Train Loss 0.3827
# Valid Loss 0.5819
# Test Bin Acc 0.7347
# Epoch 48
# Train Loss 0.3827
# Valid Loss 0.5820
# Test Bin Acc 0.7347
# Epoch 49
# Train Loss 0.3827
# Valid Loss 0.5820
# Test Bin Acc 0.7347

# %%
print('Full Model : Acc. {:.4f}     Total Params. {:10}     Fusion Params. {:10}'.format(
    full_max_accuracy, full_max_model.count_parameters(), full_max_model.count_fusion_parameters()))

print('========================================================================================')

print('L.R. Model : Acc. {:.4f}     Total Params. {:10}     Fusion Params. {:10}'.format(
    lr_max_accuracy, lr_max_model.count_parameters(), lr_max_model.count_fusion_parameters()))

print('Rank {}  Total Comp. Ratio {:5}   Fusion Comp. Ratio {:5}'.format(
    lr_max_model.fusion_layer.rank,
    full_max_model.count_parameters() / lr_max_model.count_parameters(), 
    full_max_model.count_fusion_parameters() / lr_max_model.count_fusion_parameters()))

print('========================================================================================')

print('L.R. Model 2: Acc. {:.4f}     Total Params. {:10}     Fusion Params. {:10}'.format(
    lr_max_accuracy_2, lr_max_model_2.count_parameters(), lr_max_model_2.count_fusion_parameters()))

print('Rank {}  Total Comp. Ratio {:5}   Fusion Comp. Ratio {:5}'.format(
    lr_max_model_2.fusion_layer.rank,
    full_max_model.count_parameters() / lr_max_model_2.count_parameters(), 
    full_max_model.count_fusion_parameters() / lr_max_model_2.count_fusion_parameters()))

print('========================================================================================')

print('Comp. Model: Acc. {:.4f}     Total Params. {:10}     Fusion Params. {:10}'.format(
    comp_max_accuracy, comp_max_model.count_parameters(), comp_max_model.count_fusion_parameters()))

print('Rank {}  Total Comp. Ratio {:5}   Fusion Comp. Ratio {:5}'.format(
    comp_max_model.fusion_layer.max_rank,
    full_max_model.count_parameters() / comp_max_model.count_parameters(), 
    full_max_model.count_fusion_parameters() / comp_max_model.count_fusion_parameters()))
# Out:
# Full Model : Acc. 0.7274     Total Params.   18256609     Fusion Params.   17981696
# ========================================================================================
# L.R. Model : Acc. 0.7464     Total Params.     307341     Fusion Params.      32428
# Rank 100  Total Comp. Ratio 59.401801256584704   Fusion Comp. Ratio 554.5114098926854
# ========================================================================================
# L.R. Model 2: Acc. 0.7347     Total Params.     300558     Fusion Params.      25645
# Rank 79  Total Comp. Ratio 60.74238250187984   Fusion Comp. Ratio 701.1774614934685
# ========================================================================================
# Comp. Model: Acc. 0.7522     Total Params.     300637     Fusion Params.      25724
# Rank 79  Total Comp. Ratio 60.726420899623136   Fusion Comp. Ratio 699.0241020059088

# %%
import numpy as np
full_train_time_per_epoch = np.mean(full_result['train_time'])
lr_train_time_per_epoch = np.mean(lr_result['train_time'])
lr_train_time_per_epoch_2 = np.mean(lr_result_2['train_time'])
comp_train_time_per_epoch = np.mean(comp_result['train_time'])
print("Full Model Train Time Per Epoch: {:.2f}".format(full_train_time_per_epoch))
print("L.R. Model Train Time Per Epoch: {:.2f}".format(lr_train_time_per_epoch))
print("L.R. Model 2 Train Time Per Epoch: {:.2f}".format(lr_train_time_per_epoch_2))
print("Comp. Model Train Time Per Epoch: {:.2f}".format(comp_train_time_per_epoch))
# Out:
# Full Model Train Time Per Epoch: 5.31
# L.R. Model Train Time Per Epoch: 1.31
# L.R. Model 2 Train Time Per Epoch: 1.31
# Comp. Model Train Time Per Epoch: 1.46

# %%
import time
text, audio, vision, label = test_set[:2]
tic = time.time()
output = full_max_model(text, audio, vision)
toc = time.time()
print("Full Model Inference Time: {:.4f}".format(toc - tic))
tic = time.time()
output = lr_max_model(text, audio, vision)
toc = time.time()
print("L.R. Model Inference Time: {:.4f}".format(toc - tic))
tic = time.time()
output = lr_max_model_2(text, audio, vision)
toc = time.time()
print("L.R Model 2 Inference Time: {:.4f}".format(toc - tic))
tic = time.time()
output = comp_max_model(text, audio, vision)
toc = time.time()
print("Comp. Model Inference Time: {:.4f}".format(toc - tic))
# Out:
# Full Model Inference Time: 0.0292
# L.R. Model Inference Time: 0.0050
# L.R Model 2 Inference Time: 0.0044
# Comp. Model Inference Time: 0.0045

# %%
ind = full_result['test_accuracy'].index(full_max_accuracy)
print(full_result['test_f1'][ind])

ind = lr_result['test_accuracy'].index(lr_max_accuracy)
print(lr_result['test_f1'][ind])

ind = lr_result_2['test_accuracy'].index(lr_max_accuracy_2)
print(lr_result_2['test_f1'][ind])

ind = comp_result['test_accuracy'].index(comp_max_accuracy)
print(comp_result['test_f1'][ind])
# Out:
# 0.557919621749409
# 0.6448979591836734
# 0.6591760299625469
# 0.6473029045643154
